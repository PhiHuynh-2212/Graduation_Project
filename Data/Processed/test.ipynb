# %%
import pandas as pd
import numpy as np
df_test = pd.read_csv(r"C:/FPT Polytechnic/Project Tự Làm/Điểm thi thpt 2020 - 2024/processed.csv")
df_region = pd.read_csv(r"C:\FPT Polytechnic\Graduation_Project\Data\Processed\national_examination_board_transform.csv")

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4932392 entries, 0 to 4932391
# Data columns (total 18 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   sbd        int64
#  1   toan       float64
#  2   ngu_van    float64
#  3   vat_li     float64
#  4   hoa_hoc    float64
#  5   sinh_hoc   float64
#  6   lich_su    float64
#  7   dia_li     float64
#  8   gdcd       float64
#  9   ngoai_ngu  float64
#  10  code       int64
#  11  year       int64
#  12  khtn       float64
#  13  khxh       float64
#  14  khoi_a     float64
#  15  khoi_b     float64
#  16  khoi_c     float64
#  17  khoi_d     float64
# dtypes: float64(15), int64(3)
# memory usage: 677.4 MB

# %%
df_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   code                        64 non-null     int64
#  1   national examination board  64 non-null     object
#  2   province                    64 non-null     object
#  3   regions                     63 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 2.1+ KB

# %%
df_test[df_test["code"].isnull()]
df_test = pd.merge(df_test, df_region, on='code', how='left')
df_test
# Out:
#               sbd  toan  ngu_van  vat_li  hoa_hoc  sinh_hoc  lich_su  dia_li  \
# 0        18014547   6.4     6.75     NaN      NaN       NaN     4.75    7.00
# 1        18014530   7.6     6.00     NaN      NaN       NaN     3.75    7.75
# 2        18014521   4.8     4.75     NaN      NaN       NaN     4.00    6.50
# 3        18014517   8.0     7.00     NaN      NaN       NaN     8.25    8.00
# 4        18014523   8.2     6.50    8.00      8.5       5.0      NaN     NaN
# ...           ...   ...      ...     ...      ...       ...      ...     ...
# 4932387  64007282   4.2     6.00     NaN      NaN       NaN     5.25    6.25
# 4932388  64007283   5.2     6.00     NaN      NaN       NaN     6.25    5.75
# 4932389  64007284   7.2     8.00    6.25      7.0       8.0      NaN     NaN
# 4932390  64007285   5.2     5.25     NaN      NaN       NaN     4.75    6.50
# 4932391  64007286   5.8     8.25     NaN      NaN       NaN     5.00    7.25
#
# ...

# %%
df_test[df_test["code"] == 65].shape[0]
# Out:
# 0

# %%
df_test['province'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4932392 entries, 0 to 4932391
# Data columns (total 21 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   sbd                         int64
#  1   toan                        float64
#  2   ngu_van                     float64
#  3   vat_li                      float64
#  4   hoa_hoc                     float64
#  5   sinh_hoc                    float64
#  6   lich_su                     float64
#  7   dia_li                      float64
#  8   gdcd                        float64
#  9   ngoai_ngu                   float64
#  10  code                        int64
#  11  year                        int64
#  12  khtn                        float64
#  13  khxh                        float64
#  14  khoi_a                      float64
#  15  khoi_b                      float64
#  16  khoi_c                      float64
#  17  khoi_d                      float64
# ...
